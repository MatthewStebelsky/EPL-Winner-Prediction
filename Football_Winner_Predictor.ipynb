# %%
import pandas as pd

# %%
games = pd.read_csv("data.csv", index_col=0)

# %%
games.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  15.0  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  12.6  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.6  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  23.0  8.0  16.6  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  15.3  1.0  0.0   0.0
#
#    season     team
# 0    2022  Arsenal
# 1    2022  Arsenal
# 2    2022  Arsenal
# 3    2022  Arsenal
# 4    2022  Arsenal
#
# [5 rows x 27 columns]

# %%
#Checking for any values missing from the data (All expected is present)
games["team"].value_counts()
# Out:
# Arsenal                     44
# Newcastle United            44
# Leicester City              44
# West Ham United             44
# Aston Villa                 44
# Everton                     44
# Crystal Palace              44
# Wolverhampton Wanderers     44
# Manchester City             44
# Southampton                 44
# Leeds United                44
# Brentford                   44
# Liverpool                   44
# Chelsea                     44
# Manchester United           44
# Brighton and Hove Albion    44
# Tottenham Hotspur           44
# Burnley                     38
# Watford                     38
# Norwich City                38
# Fulham                       6
# Bournemouth                  6
# Nottingham Forest            6
# Name: team, dtype: int64

# %%
games = pd.read_csv("data.csv", index_col=0)
games.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del games["comp"]
del games["notes"]

# %%
games["date"] = pd.to_datetime(games["date"])
games["target"] = (games["result"] == "W").astype("int")

# %%
games["venue_code"] = games["venue"].astype("category").cat.codes
games["opp_code"] = games["opponent"].astype("category").cat.codes
games["hour"] = games["time"].str.replace(":.+", "", regex=True).astype("int")
games["day_code"] = games["date"].dt.dayofweek

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = games[games["date"] < '2022-01-01']
test = games[games["date"] > '2022-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5984251968503937

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          242  69
# 1          135  62

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4732824427480916

# %%
grouped_games = games.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# 8  2021-09-25  12:30   Matchweek 6  Sat  Away      W  1.0  0.0
# 10 2021-10-03  16:30   Matchweek 7  Sun  Away      D  2.0  2.0
# 11 2021-10-16  15:00   Matchweek 8  Sat  Home      W  2.0  0.0
# 13 2021-10-23  17:30   Matchweek 9  Sat  Away      W  4.0  1.0
# 15 2021-10-30  15:00  Matchweek 10  Sat  Home      L  0.0  2.0
# 17 2021-11-06  12:30  Matchweek 11  Sat  Away      W  2.0  0.0
# 18 2021-11-21  14:00  Matchweek 12  Sun  Home      W  3.0  0.0
# 20 2021-11-28  14:00  Matchweek 13  Sun  Home      W  2.0  1.0
# 21 2021-12-01  20:15  Matchweek 14  Wed  Away      W  2.0  1.0
# 22 2021-12-04  17:30  Matchweek 15  Sat  Away      W  3.0  1.0
# 24 2021-12-11  12:30  Matchweek 16  Sat  Home      W  1.0  0.0
# 25 2021-12-14  20:00  Matchweek 17  Tue  Home      W  7.0  0.0
# 26 2021-12-19  14:15  Matchweek 18  Sun  Away      W  4.0  0.0
# 27 2021-12-26  15:00  Matchweek 19  Sun  Home      W  6.0  3.0
# 28 2021-12-29  20:15  Matchweek 20  Wed  Away      W  1.0  0.0
# 29 2022-01-01  12:30  Matchweek 21  Sat  Away      W  2.0  1.0
# 31 2022-01-15  12:30  Matchweek 22  Sat  Home      W  1.0  0.0
# 32 2022-01-22  17:30  Matchweek 23  Sat  Away      D  1.0  1.0
# 34 2022-02-09  19:45  Matchweek 24  Wed  Home      W  2.0  0.0
# 35 2022-02-12  17:30  Matchweek 25  Sat  Away      W  4.0  0.0
# 37 2022-02-19  17:30  Matchweek 26  Sat  Home      L  2.0  3.0
# 38 2022-02-26  17:30  Matchweek 27  Sat  Away      W  1.0  0.0
# 40 2022-03-06  16:30  Matchweek 28  Sun  Home      W  4.0  1.0
# 42 2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44 2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46 2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49 2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50 2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
# 52 2022-04-30  17:30  Matchweek 35  Sat  Away      W  4.0  0.0
# 54 2022-05-08  16:30  Matchweek 36  Sun  Home      W  5.0  0.0
# 55 2022-05-11  20:15  Matchweek 33  Wed  Away      W  5.0  1.0
# 56 2022-05-15  14:00  Matchweek 37  Sun  Away      D  2.0  2.0
# 57 2022-05-22  16:00  Matchweek 38  Sun  Home      W  3.0  2.0
# 1  2022-08-07  16:30   Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2022-08-13  15:00   Matchweek 2  Sat  Home      W  4.0  0.0
# 3  2022-08-21  16:30   Matchweek 3  Sun  Away      D  3.0  3.0
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W  6.0  0.0
# 6  2022-09-03  17:30   Matchweek 6  Sat  Away      D  1.0  1.0
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 4    Leicester City  2.9  ...    15         5    3.333333   0.333333
# 6       Southampton  1.1  ...    15         5    3.666667   0.000000
# 8           Chelsea  1.7  ...    12         5    2.000000   0.000000
# 10        Liverpool  1.2  ...    16         6    0.666667   0.000000
# 11          Burnley  1.9  ...    15         5    1.000000   0.666667
# 13         Brighton  3.9  ...    17         5    1.666667   0.666667
# 15   Crystal Palace  1.1  ...    15         5    2.666667   1.000000
# 17   Manchester Utd  2.0  ...    12         5    2.000000   1.000000
# 18          Everton  2.3  ...    14         6    2.000000   1.000000
# 20         West Ham  2.1  ...    14         6    1.666667   0.666667
# 21      Aston Villa  0.9  ...    20         2    2.333333   0.333333
# 22          Watford  3.2  ...    17         5    2.333333   0.666667
# 24           Wolves  3.5  ...    12         5    2.333333   1.000000
# 25     Leeds United  3.6  ...    20         1    2.000000   0.666667
# 26    Newcastle Utd  3.1  ...    14         6    3.666667   0.333333
# 27   Leicester City  3.4  ...    15         6    4.000000   0.000000
# 28        Brentford  0.8  ...    20         2    5.666667   1.000000
# 29          Arsenal  1.6  ...    12         5    3.666667   1.000000
# 31          Chelsea  0.7  ...    12         5    3.000000   1.333333
# 35  15.000000    5.666667    17.333333    0.333333    0.333333       0.333333
# 37  18.333333    6.333333    15.633333    0.000000    0.333333       0.666667
# 38  18.333333    5.666667    15.333333    0.000000    0.666667       1.000000
# 40  18.000000    6.333333    14.300000    0.000000    0.333333       0.666667
# 42  19.000000    7.000000    15.366667    0.333333    0.333333       0.333333
# 44  18.333333    7.333333    16.000000    0.333333    0.000000       0.000000
# 46  20.000000    6.666667    16.133333    0.333333    0.000000       0.000000
# 49  15.666667    4.666667    16.700000    0.333333    0.000000       0.000000
# 50  15.333333    5.000000    17.200000    0.333333    0.000000       0.000000
# 52  16.000000    5.333333    16.700000    0.333333    0.333333       0.333333
# 54  18.666667    6.000000    16.333333    0.000000    0.333333       0.333333
# 55  20.000000    7.333333    15.166667    0.333333    0.333333       0.333333
# 56  18.333333    6.666667    14.933333    0.333333    0.000000       0.000000
# 57  22.000000    7.000000    15.700000    1.000000    0.000000       0.333333
# 1   23.000000    5.666667    15.200000    1.000000    0.000000       0.333333
# 2   22.333333    4.333333    16.633333    1.333333    0.333333       0.666667
# 3   19.000000    4.333333    15.933333    0.666667    0.333333       0.333333
# 4   18.333333    6.000000    16.300000    0.666667    0.333333       0.333333
# 5   20.000000    7.333333    14.600000    0.333333    0.000000       0.000000
# 6   19.000000    8.000000    14.100000    0.333333    0.000000       0.000000
#
# [41 rows x 38 columns]

# %%
games_rolling = games.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
games_rolling
# Out:
#                                 date   time        round  day venue result  \
# team
# Arsenal                 4 2021-09-11  15:00  Matchweek 4  Sat  Home      W
#                         5 2021-09-18  15:00  Matchweek 5  Sat  Away      W
#                         7 2021-09-26  16:30  Matchweek 6  Sun  Home      W
#                         8 2021-10-02  17:30  Matchweek 7  Sat  Away      D
#                         9 2021-10-18  20:00  Matchweek 8  Mon  Home      D
# ...                              ...    ...          ...  ...   ...    ...
# Wolverhampton Wanderers 1 2022-08-13  15:00  Matchweek 2  Sat  Home      D
#                         2 2022-08-20  12:30  Matchweek 3  Sat  Away      L
#                         4 2022-08-28  14:00  Matchweek 4  Sun  Home      D
#                         5 2022-08-31  19:30  Matchweek 5  Wed  Away      D
#                         6 2022-09-03  15:00  Matchweek 6  Sat  Home      W
#
#                             gf   ga        opponent   xg  ...  hour  day_code  \
# team                                                      ...
# Arsenal                 4  1.0  0.0    Norwich City  2.8  ...    15         5
#                         5  1.0  0.0         Burnley  1.2  ...    15         5
#                         7  3.0  1.0       Tottenham  0.8  ...    16         6
#                         8  0.0  0.0        Brighton  0.5  ...    17         5
#                         9  2.0  2.0  Crystal Palace  1.4  ...    20         0
# ...                        ...  ...             ...  ...  ...   ...       ...
# Wolverhampton Wanderers 1  0.0  0.0          Fulham  0.7  ...    15         5
#                         2  0.0  1.0       Tottenham  0.8  ...    12         5
#                         4  1.0  1.0   Newcastle Utd  0.8  ...    14         6
#                         5  0.0  0.0     Bournemouth  1.5  ...    19         2
#                         6  1.0  0.0     Southampton  0.7  ...    15         5
#
#                            gf_rolling ga_rolling sh_rolling sot_rolling  \
# team
# Arsenal                 4    0.000000   3.000000   9.666667    2.333333
#                         5    0.333333   2.333333  12.333333    3.000000
#                         7    0.666667   1.666667  14.666667    3.000000
#                         8    1.666667   0.333333  18.333333    5.333333
#                         9    1.333333   0.333333  11.000000    4.000000
# ...                               ...        ...        ...         ...
# Wolverhampton Wanderers 1    1.000000   2.000000  13.000000    5.000000
#                         2    0.666667   1.666667   9.666667    4.000000
#                         4    0.333333   1.000000  14.000000    3.333333
#                         5    0.333333   0.666667  12.333333    2.666667
#                         6    0.333333   0.666667  15.666667    3.333333
#
#                           dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# team
# Arsenal                 4    14.600000    0.333333         0.0            0.0
#                         5    13.866667    0.333333         0.0            0.0
#                         7    14.766667    0.666667         0.0            0.0
#                         8    18.000000    0.666667         0.0            0.0
#                         9    18.966667    0.666667         0.0            0.0
# ...                                ...         ...         ...            ...
# Wolverhampton Wanderers 1    17.666667    0.666667         0.0            0.0
#                         2    17.333333    0.333333         0.0            0.0
#                         4    19.333333    0.666667         0.0            0.0
#                         5    19.600000    1.000000         0.0            0.0
#                         6    19.066667    1.000000         0.0            0.0
#
# [811 rows x 38 columns]

# %%
games_rolling.index = range(games_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(games_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5081967213114754

# %%
combined = combined.merge(games_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 17       0          0 2022-01-23  Arsenal         Burnley      D
# 18       1          0 2022-02-10  Arsenal          Wolves      W
# 19       1          0 2022-02-19  Arsenal       Brentford      W
# 20       1          0 2022-02-24  Arsenal          Wolves      W
# 21       1          1 2022-03-06  Arsenal         Watford      W
# 22       1          1 2022-03-13  Arsenal  Leicester City      W
# 23       0          1 2022-03-16  Arsenal       Liverpool      L
# 24       1          0 2022-03-19  Arsenal     Aston Villa      W
# 25       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 26       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            0 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 482         0            0 2022-08-06  Wolverhampton Wanderers   Leeds United
# 483         0            1 2022-08-20  Wolverhampton Wanderers      Tottenham
# 484         0            0 2022-08-28  Wolverhampton Wanderers  Newcastle Utd
# 485         0            0 2022-08-31  Wolverhampton Wanderers    Bournemouth
# 486         1            0 2022-09-03  Wolverhampton Wanderers    Southampton
#
#     result_x new_team_x  actual_y  predicted_y                   team_y  \
# 0          D    Arsenal         0            0                  Burnley
# 1          W    Arsenal         0            0  Wolverhampton Wanderers
# 2          W    Arsenal         0            0                Brentford
# 3          W    Arsenal         0            0  Wolverhampton Wanderers
# 4          W    Arsenal         0            0                  Watford
# ..       ...        ...       ...          ...                      ...
# 482        L     Wolves         1            0             Leeds United
# 483        L     Wolves         1            1        Tottenham Hotspur
# 484        D     Wolves         0            0         Newcastle United
# 485        D     Wolves         0            0              Bournemouth
# 486        W     Wolves         0            0              Southampton
#
#     opponent_y result_y     new_team_y
# 0      Arsenal        D        Burnley
# 1      Arsenal        L         Wolves
# 2      Arsenal        L      Brentford
# 3      Arsenal        L         Wolves
# 4      Arsenal        L        Watford
# ..         ...      ...            ...
# 482     Wolves        W   Leeds United
# 483     Wolves        W      Tottenham
# 484     Wolves        D  Newcastle Utd
# 485     Wolves        D    Bournemouth
# 486     Wolves        L    Southampton
#
# [487 rows x 13 columns]

# %%
#57/94 = 61% accuracy
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    57
# 0    37
# Name: actual_x, dtype: int64
